# %%
import pandas as pd
import numpy as np

# %%
hop_csv = "Resources/purchase_data.csv"
purchase_data = pd.read_csv('Resources/purchase_data.csv')
purchase_data.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %%
purchase_data.columns
# Out:
# Index(['Purchase ID', 'SN', 'Age', 'Gender', 'Item ID', 'Item Name', 'Price'], dtype='object')

# %%
#Calculating the total player count
total_players = len(purchase_data["SN"].value_counts())

# Create a data frame with total players named player count
player_count = pd.DataFrame({"Total Players":[total_players]})
player_count
# Out:
#    Total Players
# 0            576

# %%
#Starting the Purchasing Analysis table values

# %%
# Calculations for unique items, average price, purchase count, and revenue
num_unique_items = len((purchase_data["Item ID"]).unique())
avg_price = (purchase_data["Price"]).mean()
num_of_purchases = (purchase_data["Purchase ID"]).count()
total_rev = (purchase_data["Price"]).sum()

# Create data frame with obtained values
summary_df = pd.DataFrame({"Number of Unique Items":[number_of_unique_items],
                           "Average Price":[average_price], 
                           "Number of Purchases": [number_of_purchases], 
                           "Total Revenue": [total_revenue]})

# Format with currency style
summary_df.style.format({'Average Price':"${:,.2f}",
                         'Total Revenue': '${:,.2f}'})
# Out:
# <style type="text/css">
# </style>
# <table id="T_b8392_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Number of Unique Items</th>
#       <th class="col_heading level0 col1" >Average Price</th>
#       <th class="col_heading level0 col2" >Number of Purchases</th>
#       <th class="col_heading level0 col3" >Total Revenue</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b8392_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b8392_row0_col0" class="data row0 col0" >179</td>
#       <td id="T_b8392_row0_col1" class="data row0 col1" >$3.05</td>
#       <td id="T_b8392_row0_col2" class="data row0 col2" >780</td>
#       <td id="T_b8392_row0_col3" class="data row0 col3" >$2,379.77</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Group purchase_data by Gender
gender_stats = purchase_data.groupby("Gender")

# Count the total of screen names "SN" by gender
total_gender_count = gender_stats.nunique()["SN"]

# Total count by gender and divivde by total players 
percentage_of_players = total_gender_count / total_players * 100

# Create data frame with obtained values
gender_dems = pd.DataFrame({"Percentage of Players": percentage_of_players, "Total Count": total_gender_count})

# Format the data frame with no index name in the corner
gender_dems.index.name = None

# Format the values sorted by total count in descending order, and two decimal places for the percentage
gender_dems.sort_values(["Total Count"], ascending = False).style.format({"Percentage of Players":"{:.2f}"})
# Out:
# <style type="text/css">
# </style>
# <table id="T_041fb_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Percentage of Players</th>
#       <th class="col_heading level0 col1" >Total Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_041fb_level0_row0" class="row_heading level0 row0" >Male</th>
#       <td id="T_041fb_row0_col0" class="data row0 col0" >84.03</td>
#       <td id="T_041fb_row0_col1" class="data row0 col1" >484</td>
#     </tr>
#     <tr>
#       <th id="T_041fb_level0_row1" class="row_heading level0 row1" >Female</th>
#       <td id="T_041fb_row1_col0" class="data row1 col0" >14.06</td>
#       <td id="T_041fb_row1_col1" class="data row1 col1" >81</td>
#     </tr>
#     <tr>
#       <th id="T_041fb_level0_row2" class="row_heading level0 row2" >Other / Non-Disclosed</th>
#       <td id="T_041fb_row2_col0" class="data row2 col0" >1.91</td>
# ...

# %%
#Purchasing Analysis
# Count the total purchases by gender 
purchase_count = gender_stats["Purchase ID"].count()

# Average purchase prices by gender
avg_purchase_price = gender_stats["Price"].mean()

# Average purchase total by gender 
avg_purchase_total = gender_stats["Price"].sum()

# Average purchase total by gender divivded by purchase count by unique shoppers
avg_ppp = avg_purchase_total/total_gender_count

# Create data frame with obtained values 
gender_demographics = pd.DataFrame({"Purchase Count": purchase_count, 
                                    "Average Purchase Price": avg_purchase_price,
                                    "Average Purchase Value":avg_purchase_total,
                                    "Avg Purchase Total per Person": avg_ppp})

# Provide index in top left as "Gender"
gender_demographics.index.name = "Gender"

# Format with currency style
gender_demographics.style.format({"Average Purchase Value":"${:,.2f}",
                                  "Average Purchase Price":"${:,.2f}",
                                  "Avg Purchase Total per Person":"${:,.2f}"})
# Out:
# <style type="text/css">
# </style>
# <table id="T_4b562_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Purchase Count</th>
#       <th class="col_heading level0 col1" >Average Purchase Price</th>
#       <th class="col_heading level0 col2" >Average Purchase Value</th>
#       <th class="col_heading level0 col3" >Avg Purchase Total per Person</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Gender</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4b562_level0_row0" class="row_heading level0 row0" >Female</th>
#       <td id="T_4b562_row0_col0" class="data row0 col0" >113</td>
#       <td id="T_4b562_row0_col1" class="data row0 col1" >$3.20</td>
# ...

# %%
#Age Demographics

# Establish bins for ages
age_bins = [0, 9.90, 14.90, 19.90, 24.90, 29.90, 34.90, 39.90, 99999]
group_names = ["<10", "10-14", "15-19", "20-24", "25-29", "30-34", "35-39", "40+"]

# Segment and sort age values into bins established above
purchase_data["Age Group"] = pd.cut(purchase_data["Age"],age_bins, labels=group_names)
purchase_data

# Create new data frame with the added "Age Group" and group it
age_grouped = purchase_data.groupby("Age Group")

# Count total players by age category
tot_count_age = age_grouped["SN"].nunique()

# Calculate percentages by age category 
percentage_by_age = (total_count_age/total_players) * 100

# Create data frame with obtained values
age_demographics = pd.DataFrame({"Total Count": tot_count_age, "Percentage of Players": percentage_by_age})

# Format the data frame with no index name in the corner
age_demographics.index.name = None

# Format percentage with two decimal places 
age_demographics.style.format({"Percentage of Players":"{:,.2f}"})
# Out:
# <style type="text/css">
# </style>
# <table id="T_85e8e_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Total Count</th>
#       <th class="col_heading level0 col1" >Percentage of Players</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_85e8e_level0_row0" class="row_heading level0 row0" ><10</th>
#       <td id="T_85e8e_row0_col0" class="data row0 col0" >17</td>
#       <td id="T_85e8e_row0_col1" class="data row0 col1" >2.95</td>
#     </tr>
#     <tr>
#       <th id="T_85e8e_level0_row1" class="row_heading level0 row1" >10-14</th>
#       <td id="T_85e8e_row1_col0" class="data row1 col0" >22</td>
#       <td id="T_85e8e_row1_col1" class="data row1 col1" >3.82</td>
#     </tr>
#     <tr>
#       <th id="T_85e8e_level0_row2" class="row_heading level0 row2" >15-19</th>
#       <td id="T_85e8e_row2_col0" class="data row2 col0" >107</td>
# ...

# %%
# Count purchases by age group
purch_count_age = age_grouped["Purchase ID"].count()

# Obtain average purchase price by age group 
avg_purch_price_age = age_grouped["Price"].mean()

# Calculate total purchase value by age group 
total_purchase_value = age_grouped["Price"].sum()

# Calculate the average purchase per person in the age group 
avg_purchase_per_person_age = total_purchase_value/total_count_age

# Create data frame with obtained values
age_demographics = pd.DataFrame({"Purchase Count": purchase_count_age,
                                 "Average Purchase Price": avg_purchase_price_age,
                                 "Total Purchase Value":total_purchase_value,
                                 "Average Total Purchase per Person": avg_purchase_per_person_age})

# Format the data frame with no index name in the corner
age_demographics.index.name = None

# Format with currency style
age_demographics.style.format({"Average Purchase Price":"${:,.2f}",
                               "Total Purchase Value":"${:,.2f}",
                               "Average Total Purchase per Person":"${:,.2f}"})
# Out:
# <style type="text/css">
# </style>
# <table id="T_3836d_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Purchase Count</th>
#       <th class="col_heading level0 col1" >Average Purchase Price</th>
#       <th class="col_heading level0 col2" >Total Purchase Value</th>
#       <th class="col_heading level0 col3" >Average Total Purchase per Person</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3836d_level0_row0" class="row_heading level0 row0" ><10</th>
#       <td id="T_3836d_row0_col0" class="data row0 col0" >23</td>
#       <td id="T_3836d_row0_col1" class="data row0 col1" >$3.35</td>
#       <td id="T_3836d_row0_col2" class="data row0 col2" >$77.13</td>
#       <td id="T_3836d_row0_col3" class="data row0 col3" >$4.54</td>
#     </tr>
#     <tr>
#       <th id="T_3836d_level0_row1" class="row_heading level0 row1" >10-14</th>
#       <td id="T_3836d_row1_col0" class="data row1 col0" >28</td>
# ...
